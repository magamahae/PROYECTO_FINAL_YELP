# %% [markdown]
# # ETL_Google

# %% [markdown]
# Importamos las librerias necesarias para comenzar con el proceso de ETL

# %%
import os
import json 
import numpy as np
import pandas as pd
import herramientas
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Leemos los archivos json de la carpeta "Califronia"

# %%
#Funcion para leer el estado de California
def read_json_files(folder_path):
    data = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".json"):
            file_path = os.path.join(folder_path, file_name)
            with open(file_path, 'r') as file:
                for line in file:
                    line = line.strip()
                    if line:
                        try:
                            json_obj = json.loads(line)
                            data.append(json_obj)
                        except json.JSONDecodeError:
                            continue

    df = pd.DataFrame(data)
    return df

# %% [markdown]
# Leemos cada json y lo convertimos en un dataframe y lo agregamos a una lista de dataframe

# %%
folder_path = "data/google/reviews-estados/review-California"
df_list = []
df_california = read_json_files(folder_path)
df_list.append(df_california)

# %% [markdown]
# Unimos todos los dataframes generados en uno

# %%
df_california_concat = pd.concat(df_list, ignore_index=True)

# %%
df_california_concat
# Out:
#                        user_id                 name           time  rating  \
# 0        108991152262655788985              Song Ro  1609909927056       5
# 1        111290322219796215751          Rafa Robles  1612849648663       5
# 2        112640357449611959087            David Han  1583643882296       4
# 3        117440349723823658676          Anthony Kim  1551938216355       5
# 4        100580770836123539210        Mario Marzouk  1494910901933       5
# ...                        ...                  ...            ...     ...
# 2699995  111342337087018931578          Byunguk Kim  1573362674409       5
# 2699996  108081820251273699976  Ceveda Craytonhooks  1580608853411       5
# 2699997  117591383135333249676     Natacha Thompson  1528597806165       5
# 2699998  112426610655792883265       Eleanor Aikins  1551203379295       5
# 2699999  112219943666423225464            Thai Love  1553880485978       5
#
#                                                       text  \
# 0                             Love there korean rice cake.
# 1                                           Good very good
# 2         They make Korean traditional food very properly.
# 3                           Short ribs are very delicious.
# 4             Great food and prices the portions are large
# ...                                                    ...
# 2699995                                               None
# 2699996  Beautiful salon. The staff and atmosphere were...
# 2699997  Flo is a great beautician.   She is very patie...
# 2699998  I Been going to have a variety of hair style a...
# 2699999  Teri is awesome she is a dread loc master. She...
#
#                                                       pics  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 2699995                                               None
# 2699996                                               None
# 2699997  [{'url': ['https://lh5.googleusercontent.com/p...
# 2699998                                               None
# 2699999                                               None
#
#                                                       resp  \
# 0                                                     None
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 2699995                                               None
# 2699996                                               None
# 2699997  {'time': 1528598932831, 'text': 'Thank you!  I...
# 2699998                                               None
# 2699999                                               None
#
#                                        gmap_id
# 0        0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 1        0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 2        0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 3        0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 4        0x80c2c778e3b73d33:0xbdc58662a4a97d49
# ...                                        ...
# 2699995  0x80c2bea30829f279:0x39aa953ee93734ed
# 2699996  0x8094675073616747:0x9f935a9b9046a9ba
# 2699997  0x8094675073616747:0x9f935a9b9046a9ba
# 2699998  0x8094675073616747:0x9f935a9b9046a9ba
# 2699999  0x8094675073616747:0x9f935a9b9046a9ba
#
# [2700000 rows x 8 columns]

# %% [markdown]
# Elimino las columnas 'pics' y 'resp'

# %%
#Dropeamos las columnas que no usaremos
df_california_concat.drop(["pics", "resp"], axis=1, inplace=True)

# %% [markdown]
# Cambiamos el formato de la columna 'time'

# %%
# Convertir la columna "time" al formato adecuado
df_california_concat['time'] = pd.to_datetime(df_california_concat['time'], unit='ms')

# %% [markdown]
# Creamos las columnas  'date' y 'hour'

# %%
#Creamos dos columnas (date y hour) para ser extraidos de la columna time y convertir al formato adecuado 
df_california_concat['hour'] = pd.to_datetime(df_california_concat['time']).dt.strftime('%H:%M:%S')
df_california_concat['date'] = pd.to_datetime(df_california_concat['time']).dt.strftime('%Y-%m-%d')

# %% [markdown]
# Elimino la columna 'time'

# %%
df_california_concat.drop(["time"], axis=1, inplace=True)

# %% [markdown]
# Verifico valores nulos

# %%
herramientas.verifica_tipo_y_nulos(df_california_concat)
# Out:
#   nombre_campo                           tipo_datos  no_nulos_%  nulos_%  \
# 0      user_id                      [<class 'str'>]      100.00     0.00
# 1         name                      [<class 'str'>]      100.00     0.00
# 2       rating                      [<class 'int'>]      100.00     0.00
# 3         text  [<class 'str'>, <class 'NoneType'>]       56.63    43.37
# 4      gmap_id                      [<class 'str'>]      100.00     0.00
# 5         hour                      [<class 'str'>]      100.00     0.00
# 6         date                      [<class 'str'>]      100.00     0.00
#
#      nulos
# 0        0
# 1        0
# 2        0
# 3  1170964
# 4        0
# 5        0
# 6        0

# %% [markdown]
# Observamos el dataframe

# %%
df_california_concat
# Out:
#                        user_id                 name  rating  \
# 0        108991152262655788985              Song Ro       5
# 1        111290322219796215751          Rafa Robles       5
# 2        112640357449611959087            David Han       4
# 3        117440349723823658676          Anthony Kim       5
# 4        100580770836123539210        Mario Marzouk       5
# ...                        ...                  ...     ...
# 2699995  111342337087018931578          Byunguk Kim       5
# 2699996  108081820251273699976  Ceveda Craytonhooks       5
# 2699997  117591383135333249676     Natacha Thompson       5
# 2699998  112426610655792883265       Eleanor Aikins       5
# 2699999  112219943666423225464            Thai Love       5
#
#                                                       text  \
# 0                             Love there korean rice cake.
# 1                                           Good very good
# 2         They make Korean traditional food very properly.
# 3                           Short ribs are very delicious.
# 4             Great food and prices the portions are large
# ...                                                    ...
# 2699995                                               None
# 2699996  Beautiful salon. The staff and atmosphere were...
# 2699997  Flo is a great beautician.   She is very patie...
# 2699998  I Been going to have a variety of hair style a...
# 2699999  Teri is awesome she is a dread loc master. She...
#
#                                        gmap_id      hour        date
# 0        0x80c2c778e3b73d33:0xbdc58662a4a97d49  05:12:07  2021-01-06
# 1        0x80c2c778e3b73d33:0xbdc58662a4a97d49  05:47:28  2021-02-09
# 2        0x80c2c778e3b73d33:0xbdc58662a4a97d49  05:04:42  2020-03-08
# 3        0x80c2c778e3b73d33:0xbdc58662a4a97d49  05:56:56  2019-03-07
# 4        0x80c2c778e3b73d33:0xbdc58662a4a97d49  05:01:41  2017-05-16
# ...                                        ...       ...         ...
# 2699995  0x80c2bea30829f279:0x39aa953ee93734ed  05:11:14  2019-11-10
# 2699996  0x8094675073616747:0x9f935a9b9046a9ba  02:00:53  2020-02-02
# 2699997  0x8094675073616747:0x9f935a9b9046a9ba  02:30:06  2018-06-10
# 2699998  0x8094675073616747:0x9f935a9b9046a9ba  17:49:39  2019-02-26
# 2699999  0x8094675073616747:0x9f935a9b9046a9ba  17:28:05  2019-03-29
#
# [2700000 rows x 7 columns]

# %% [markdown]
# Exporto los datos en un archivo csv

# %%
# Exportar el DataFrame
df_california_concat.to_csv('california.csv', escapechar='\\', index=False)

# %% [markdown]
# Leemos los archivos json de la carpeta "Florida"

# %%
#Funcion para leer el estado de Florida
def read_json_files(folder_path):
    data = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".json"):
            file_path = os.path.join(folder_path, file_name)
            with open(file_path, 'r') as file:
                for line in file:
                    line = line.strip()
                    if line:
                        try:
                            json_obj = json.loads(line)
                            data.append(json_obj)
                        except json.JSONDecodeError:
                            continue

    df = pd.DataFrame(data)
    return df

# %% [markdown]
# Leemos cada json y lo convertimos en un dataframe y lo agregamos a una lista de dataframe

# %%
folder_path = "data/google/reviews-estados/review-Florida"
df_list = []
df_florida = read_json_files(folder_path)
df_list.append(df_florida)

# %% [markdown]
# Unimos todos los dataframes generados en uno

# %%
df_florida_concat = pd.concat(df_list, ignore_index=True)

# %%
df_florida_concat
# Out:
#                        user_id               name           time  rating  \
# 0        101471856155148729010    Julie A. Gerber  1628003250740       1
# 1        115477234789038326051   Martin Sheffield  1595031217005       5
# 2        101805010244892834381       Brian Truett  1522924253567       5
# 3        106344422881493743981           Tina Sun  1467907819586       1
# 4        100875113069561776529       James Haynes  1480683415081       5
# ...                        ...                ...            ...     ...
# 2849995  100287714800809186330      James Rudolph  1617305583696       5
# 2849996  114098933097423358884  Vincent Alexander  1581817848416       3
# 2849997  112344804812177444770         Brett Owen  1551240010030       5
# 2849998  105446471831430265409       ashly kindle  1521152570004       5
# 2849999  108743281657436212879       Jomarra Auge  1536462690218       5
#
#                                                       text  pics  \
# 0        Update: Their “reply” to my review amounted to...  None
# 1        He's a knowledgeable doctor but the way he run...  None
# 2        Best doctor I've ever had, I never wait to be ...  None
# 3        I was told he is a good doctor. I was trying t...  None
# 4        Takes the time to actually get to know his pat...  None
# ...                                                    ...   ...
# 2849995                                               None  None
# 2849996                                               None  None
# 2849997                                               None  None
# 2849998                                               None  None
# 2849999                                               None  None
#
#                                                       resp  \
# 0        {'time': 1627042799532, 'text': 'Thank you for...
# 1        {'time': 1582464056733, 'text': 'Thank you for...
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 2849995      {'time': 1617561671234, 'text': 'Thank you!'}
# 2849996                                               None
# 2849997                                               None
# 2849998  {'time': 1516914199348, 'text': 'Thank you, As...
# 2849999  {'time': 1536463333138, 'text': 'Thank you, Mr...
#
#                                        gmap_id
# 0        0x8893863ea87bd5dd:0x9383ebf973e74abb
# 1        0x8893863ea87bd5dd:0x9383ebf973e74abb
# 2        0x8893863ea87bd5dd:0x9383ebf973e74abb
# 3        0x8893863ea87bd5dd:0x9383ebf973e74abb
# 4        0x8893863ea87bd5dd:0x9383ebf973e74abb
# ...                                        ...
# 2849995  0x8890966585e36d3f:0x131d47c2c60a8d31
# 2849996  0x8890966585e36d3f:0x131d47c2c60a8d31
# 2849997  0x8890966585e36d3f:0x131d47c2c60a8d31
# 2849998  0x8890966585e36d3f:0x131d47c2c60a8d31
# 2849999  0x8890966585e36d3f:0x131d47c2c60a8d31
#
# [2850000 rows x 8 columns]

# %% [markdown]
# Elimino las columnas 'pics' y 'resp'

# %%
#Dropeamos las columnas que no usaremos
df_florida_concat.drop(["pics", "resp"], axis=1, inplace=True)

# %% [markdown]
# Cambiamos el formato de la columna 'time'

# %%
# Convertir la columna "time" al formato adecuado
df_florida_concat['time'] = pd.to_datetime(df_florida_concat['time'], unit='ms')

# %% [markdown]
# Creamos las columnas  'date' y 'hour'

# %%
#Creamos dos columnas (date y hour) para ser extraidos de la columna time y convertir al formato adecuado 
df_florida_concat['hour'] = pd.to_datetime(df_florida_concat['time']).dt.strftime('%H:%M:%S')
df_florida_concat['date'] = pd.to_datetime(df_florida_concat['time']).dt.strftime('%Y-%m-%d')

# %% [markdown]
# Elimino la columna 'time'

# %%
df_florida_concat.drop(["time"], axis=1, inplace=True)

# %%
herramientas.verifica_tipo_y_nulos(df_florida_concat)
# Out:
#   nombre_campo                           tipo_datos  no_nulos_%  nulos_%  \
# 0      user_id                      [<class 'str'>]      100.00     0.00
# 1         name                      [<class 'str'>]      100.00     0.00
# 2       rating                      [<class 'int'>]      100.00     0.00
# 3         text  [<class 'str'>, <class 'NoneType'>]       62.12    37.88
# 4      gmap_id                      [<class 'str'>]      100.00     0.00
# 5         hour                      [<class 'str'>]      100.00     0.00
# 6         date                      [<class 'str'>]      100.00     0.00
#
#      nulos
# 0        0
# 1        0
# 2        0
# 3  1079510
# 4        0
# 5        0
# 6        0

# %%
# Exportar el DataFrame
df_florida_concat.to_csv('florida.csv', escapechar='\\', index=False)

# %% [markdown]
# Leemos los archivos json de la carpeta "Illinois"

# %%
#Funcion para leer el estado de Illinois
def read_json_files(folder_path):
    data = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".json"):
            file_path = os.path.join(folder_path, file_name)
            with open(file_path, 'r') as file:
                for line in file:
                    line = line.strip()
                    if line:
                        try:
                            json_obj = json.loads(line)
                            data.append(json_obj)
                        except json.JSONDecodeError:
                            continue

    df = pd.DataFrame(data)
    return df

# %% [markdown]
# Leemos cada json y lo convertimos en un dataframe y lo agregamos a una lista de dataframe

# %%
folder_path = "data/google/reviews-estados/review-Illinois"
df_list = []
df_illinois = read_json_files(folder_path)
df_list.append(df_illinois)

# %% [markdown]
# Unimos todos los dataframes generados en uno

# %%
df_illinois_concat = pd.concat(df_list, ignore_index=True)

# %%
df_illinois_concat
# Out:
#                        user_id             name           time  rating  \
# 0        109442577269176737834    Jim LeBurkien  1571842572977       5
# 1        100924480938771474648     Steve Muscat  1561679275695       5
# 2        100813976190002245469  Fletcher Oliver  1572719516502       5
# 3        110168499961967096526    Daniel Chavez  1572641473424       5
# 4        108990598812734370097  David Ferdinand  1561483351910       4
# ...                        ...              ...            ...     ...
# 2099995  105552273253338237445      Cindy Neath  1546825827465       5
# 2099996  102035592083831756668      David Mauer  1541157502008       5
# 2099997  100212235055035923068   Bloodkisses333  1517804540149       5
# 2099998  109400103612749522118  Kevin Sircloumb  1553131495401       4
# 2099999  116175186720332752318    Phillip Feltz  1499839359853       5
#
#                                                       text  pics  resp  \
# 0        Great selection of used and collectible toys. ...  None  None
# 1                                 Great visit as usual. 👍😊  None  None
# 2                                                     None  None  None
# 3                                                     None  None  None
# 4                                                     None  None  None
# ...                                                    ...   ...   ...
# 2099995                                          Like them  None  None
# 2099996                                          Loved It!  None  None
# 2099997                                 Local and awesome!  None  None
# 2099998                  Very convenient to get in and out  None  None
# 2099999               The only place we shop for our pets.  None  None
#
#                                        gmap_id
# 0        0x880f0f1b32155555:0x8347e0c971acb955
# 1        0x880f0f1b32155555:0x8347e0c971acb955
# 2        0x880f0f1b32155555:0x8347e0c971acb955
# 3        0x880f0f1b32155555:0x8347e0c971acb955
# 4        0x880f0f1b32155555:0x8347e0c971acb955
# ...                                        ...
# 2099995  0x8808bbdd68f8761b:0x8c518beb56b4f3ca
# 2099996  0x8808bbdd68f8761b:0x8c518beb56b4f3ca
# 2099997  0x8808bbdd68f8761b:0x8c518beb56b4f3ca
# 2099998  0x8808bbdd68f8761b:0x8c518beb56b4f3ca
# 2099999  0x8808bbdd68f8761b:0x8c518beb56b4f3ca
#
# [2100000 rows x 8 columns]

# %% [markdown]
# Elimino las columnas 'pics' y 'resp'

# %%
#Dropeamos las columnas que no usaremos
df_illinois_concat.drop(["pics", "resp"], axis=1, inplace=True)

# %% [markdown]
# Cambiamos el formato de la columna 'time'

# %%
# Convertir la columna "time" al formato adecuado
df_illinois_concat['time'] = pd.to_datetime(df_illinois_concat['time'], unit='ms')

# %% [markdown]
# Creamos las columnas  'date' y 'hour'

# %%
#Creamos dos columnas (date y hour) para ser extraidos de la columna time y convertir al formato adecuado 
df_illinois_concat['hour'] = pd.to_datetime(df_illinois_concat['time']).dt.strftime('%H:%M:%S')
df_illinois_concat['date'] = pd.to_datetime(df_illinois_concat['time']).dt.strftime('%Y-%m-%d')

# %% [markdown]
# Elimino la columan 'time'

# %%
df_illinois_concat.drop(["time"], axis=1, inplace=True)

# %%
herramientas.verifica_tipo_y_nulos(df_illinois_concat)
# Out:
#   nombre_campo                           tipo_datos  no_nulos_%  nulos_%  \
# 0      user_id                      [<class 'str'>]      100.00     0.00
# 1         name                      [<class 'str'>]      100.00     0.00
# 2       rating                      [<class 'int'>]      100.00     0.00
# 3         text  [<class 'str'>, <class 'NoneType'>]       56.56    43.44
# 4      gmap_id                      [<class 'str'>]      100.00     0.00
# 5         hour                      [<class 'str'>]      100.00     0.00
# 6         date                      [<class 'str'>]      100.00     0.00
#
#     nulos
# 0       0
# 1       0
# 2       0
# 3  912218
# 4       0
# 5       0
# 6       0

# %%
# Exportar el DataFrame
df_illinois_concat.to_csv('illinois.csv', escapechar='\\', index=False)

# %% [markdown]
# Leemos los archivos json de la carpeta "New York"

# %%
#Funcion para leer el estado de New York
def read_json_files(folder_path):
    data = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".json"):
            file_path = os.path.join(folder_path, file_name)
            with open(file_path, 'r') as file:
                for line in file:
                    line = line.strip()
                    if line:
                        try:
                            json_obj = json.loads(line)
                            data.append(json_obj)
                        except json.JSONDecodeError:
                            continue

    df = pd.DataFrame(data)
    return df

# %% [markdown]
# Leemos cada json y lo convertimos en un dataframe y lo agregamos a una lista de dataframe

# %%
folder_path = "data/google/reviews-estados/review-New_York"
df_list = []
df_new_york= read_json_files(folder_path)
df_list.append(df_new_york)

# %% [markdown]
# Unimos todos los dataframes generados en uno

# %%
df_new_york_concat = pd.concat(df_list, ignore_index=True)

# %%
df_new_york_concat
# Out:
#                        user_id              name           time  rating  \
# 0        113722104692308235141    Alvin Martinez  1603494795361       5
# 1        107293441492109320298   Johnnie Jackson  1620157037403       1
# 2        100378585801819400296      Manie Blazer  1597431662039       5
# 3        114998161153019826512    Fashion Fiinds  1543773862044       5
# 4        117178185728422297915    Andres Rieloff  1597279097718       1
# ...                        ...               ...            ...     ...
# 2699995  115088845698717434859       Gourav Saha  1555437628373       4
# 2699996  111706397232791116806       jenn mosher  1462985945347       5
# 2699997  108369784075976765619      Michele Huck  1573877341097       5
# 2699998  100786787316351751498           Frank B  1603835563283       5
# 2699999  104190915147086572085  Vincent Viscanti  1561768469200       5
#
#                                                       text  \
# 0        I'm late to posting this but this store especi...
# 1        Very dissatisfied I did not get my phone the p...
# 2        Excellent very well done with professional car...
# 3        Basing my review strictly on the service I rec...
# 4        Bad! Disorganized. I'm being totally honest. I...
# ...                                                    ...
# 2699995                                               None
# 2699996                                               None
# 2699997                                               None
# 2699998                                               None
# 2699999                                               None
#
#                                                       pics  \
# 0        [{'url': ['https://lh5.googleusercontent.com/p...
# 1                                                     None
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 2699995                                               None
# 2699996                                               None
# 2699997                                               None
# 2699998                                               None
# 2699999                                               None
#
#                                                       resp  \
# 0                                                     None
# 1        {'time': 1620268360920, 'text': 'We pride ours...
# 2                                                     None
# 3        {'time': 1543855317372, 'text': 'Thanks for th...
# 4                                                     None
# ...                                                    ...
# 2699995                                               None
# 2699996                                               None
# 2699997                                               None
# 2699998                                               None
# 2699999                                               None
#
#                                        gmap_id
# 0          0x89c25fc9494dce47:0x6d63c807b59a55
# 1          0x89c25fc9494dce47:0x6d63c807b59a55
# 2          0x89c25fc9494dce47:0x6d63c807b59a55
# 3          0x89c25fc9494dce47:0x6d63c807b59a55
# 4          0x89c25fc9494dce47:0x6d63c807b59a55
# ...                                        ...
# 2699995  0x89de0b8a0905153d:0x976fc4a006084f03
# 2699996  0x89de0b8a0905153d:0x976fc4a006084f03
# 2699997  0x89de0b8a0905153d:0x976fc4a006084f03
# 2699998  0x89de0b8a0905153d:0x976fc4a006084f03
# 2699999  0x89de0b8a0905153d:0x976fc4a006084f03
#
# [2700000 rows x 8 columns]

# %% [markdown]
# Elimino las columnas 'pics' y 'resp'

# %%
#Dropeamos las columnas que no usaremos
df_new_york_concat.drop(["pics", "resp"], axis=1, inplace=True)

# %% [markdown]
# Cambiamos el formato de la columna 'time'

# %%
# Convertir la columna "time" al formato adecuado
df_new_york_concat['time'] = pd.to_datetime(df_new_york_concat['time'], unit='ms')

# %% [markdown]
# Creamos las columnas  'date' y 'hour'

# %%
#Creamos dos columnas (date y hour) para ser extraidos de la columna time y convertir al formato adecuado 
df_new_york_concat['hour'] = pd.to_datetime(df_new_york_concat['time']).dt.strftime('%H:%M:%S')
df_new_york_concat['date'] = pd.to_datetime(df_new_york_concat['time']).dt.strftime('%Y-%m-%d')

# %% [markdown]
# Elimino la columna 'time'

# %%
df_new_york_concat.drop(["time"], axis=1, inplace=True)

# %%
herramientas.verifica_tipo_y_nulos(df_new_york_concat)
# Out:
#   nombre_campo                           tipo_datos  no_nulos_%  nulos_%  \
# 0      user_id                      [<class 'str'>]       100.0      0.0
# 1         name                      [<class 'str'>]       100.0      0.0
# 2       rating                      [<class 'int'>]       100.0      0.0
# 3         text  [<class 'str'>, <class 'NoneType'>]        56.9     43.1
# 4      gmap_id                      [<class 'str'>]       100.0      0.0
# 5         hour                      [<class 'str'>]       100.0      0.0
# 6         date                      [<class 'str'>]       100.0      0.0
#
#      nulos
# 0        0
# 1        0
# 2        0
# 3  1163593
# 4        0
# 5        0
# 6        0

# %%
# Exportar el DataFrame
df_new_york_concat.to_csv('new_york.csv', escapechar='\\', index=False)

# %% [markdown]
# Leemos los archivos json de la carpeta "Texas"

# %%
#Funcion para leer el estado de Texas
def read_json_files(folder_path):
    data = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".json"):
            file_path = os.path.join(folder_path, file_name)
            with open(file_path, 'r') as file:
                for line in file:
                    line = line.strip()
                    if line:
                        try:
                            json_obj = json.loads(line)
                            data.append(json_obj)
                        except json.JSONDecodeError:
                            continue

    df = pd.DataFrame(data)
    return df

# %% [markdown]
# Leemos cada json y lo convertimos en un dataframe y lo agregamos a una lista de dataframe

# %%
folder_path = "data/google/reviews-estados/review-Texas"
df_list = []
df_texas= read_json_files(folder_path)
df_list.append(df_texas)

# %% [markdown]
# Unimos todos los dataframes generados en uno

# %%
df_texas_concat = pd.concat(df_list, ignore_index=True)

# %%
df_texas_concat
# Out:
#                        user_id              name           time  rating  \
# 0        110545299078970317447    Kimberly Feger  1625431734826       5
# 1        103619788097506115343     Briana Streit  1568336283913       2
# 2        101916663109091637233   Sylvia Caudillo  1519873586872       1
# 3        117870898304582507607     Ginger Kinyon  1571638384637       1
# 4        110397346115416712442  Angeles Arellano  1546568877087       1
# ...                        ...               ...            ...     ...
# 2296819  102168135687638614085        t williams  1562883151018       5
# 2296820  105417309184712126911        Erika Lira  1532009672494       5
# 2296821  110785699186536003973         Jon Brent  1567968578697       5
# 2296822  109167601957430874067       lunna cabal  1506476840285       4
# 2296823  101270090075117497134   Michelle Torres  1555551049893       5
#
#                                                       text  pics  resp  \
# 0        The pharmacist, Erin, is phenomenal. She was s...  None  None
# 1        I gave them 2 stars because they offer prescri...  None  None
# 2        If I could put minus stars I would. This has t...  None  None
# 3                           Please fix your restroom doors  None  None
# 4        This pharmacy Walmart dose not work not come a...  None  None
# ...                                                    ...   ...   ...
# 2296819                                               None  None  None
# 2296820                                               None  None  None
# 2296821                                               None  None  None
# 2296822                                               None  None  None
# 2296823                                               None  None  None
#
#                                        gmap_id
# 0        0x864c3998b8d8dc83:0x57ffabe1e2322320
# 1        0x864c3998b8d8dc83:0x57ffabe1e2322320
# 2        0x864c3998b8d8dc83:0x57ffabe1e2322320
# 3        0x864c3998b8d8dc83:0x57ffabe1e2322320
# 4        0x864c3998b8d8dc83:0x57ffabe1e2322320
# ...                                        ...
# 2296819  0x8640d215ff1e43e5:0xaeeb5211a25191f4
# 2296820  0x8640d215ff1e43e5:0xaeeb5211a25191f4
# 2296821  0x8640d215ff1e43e5:0xaeeb5211a25191f4
# 2296822  0x8640d215ff1e43e5:0xaeeb5211a25191f4
# 2296823  0x8640d215ff1e43e5:0xaeeb5211a25191f4
#
# [2296824 rows x 8 columns]

# %% [markdown]
# Elimino las columnas 'pics' y 'resp'

# %%
#Dropeamos las columnas que no usaremos
df_texas_concat.drop(["pics", "resp"], axis=1, inplace=True)

# %% [markdown]
# Cambiamos el formato de la columna 'time'

# %%
# Convertir la columna "time" al formato adecuado
df_texas_concat['time'] = pd.to_datetime(df_texas_concat['time'], unit='ms')

# %%
#Creamos dos columnas (date y hour) para ser extraidos de la columna time y convertir al formato adecuado 
df_texas_concat['hour'] = pd.to_datetime(df_texas_concat['time']).dt.strftime('%H:%M:%S')
df_texas_concat['date'] = pd.to_datetime(df_texas_concat['time']).dt.strftime('%Y-%m-%d')

# %% [markdown]
# Elimino la columna 'time'

# %%
df_texas_concat.drop(["time"], axis=1, inplace=True)

# %%
herramientas.verifica_tipo_y_nulos(df_texas_concat)
# Out:
#   nombre_campo                           tipo_datos  no_nulos_%  nulos_%  \
# 0      user_id                      [<class 'str'>]      100.00     0.00
# 1         name                      [<class 'str'>]      100.00     0.00
# 2       rating                      [<class 'int'>]      100.00     0.00
# 3         text  [<class 'str'>, <class 'NoneType'>]       59.98    40.02
# 4      gmap_id                      [<class 'str'>]      100.00     0.00
# 5         hour                      [<class 'str'>]      100.00     0.00
# 6         date                      [<class 'str'>]      100.00     0.00
#
#     nulos
# 0       0
# 1       0
# 2       0
# 3  919209
# 4       0
# 5       0
# 6       0

# %%
# Exportar el DataFrame
df_texas_concat.to_csv('texas.csv', escapechar='\\', index=False)

# %% [markdown]
# Abrimos la carpeta de Sitios

# %%
#Funcion para abrir carpeta de metadata-sitios
def merge_json_files(folder_path):
    merged_data = []  # Lista para almacenar los objetos JSON combinados

    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            filepath = os.path.join(folder_path, filename)
            with open(filepath) as file:
                for line in file:
                    try:
                        obj = json.loads(line)
                        merged_data.append(obj)
                    except json.JSONDecodeError as e:
                        print(f"Error al decodificar JSON en el archivo {filename}: {str(e)}")

    df = pd.DataFrame(merged_data)  # Crear DataFrame a partir de los objetos JSON
    return df

# Ejemplo de uso
folder_path = 'data/google/metadata-sitios'
df_sitios= merge_json_files(folder_path)

# %%
df_sitios
# Out:
#                                    name  \
# 0                       Porter Pharmacy
# 1                          City Textile
# 2                          San Soo Dang
# 3                          Nova Fabrics
# 4                      Nobel Textile Co
# ...                                 ...
# 1099999  Farmers Branch Shopping Center
# 1100000                  Domino's Pizza
# 1100001         Bullseye Shooting Range
# 1100002                         Cha Spa
# 1100003     Clean Touch Carpet Services
#
#                                                    address  \
# 0        Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1        City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2        San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3        Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4        Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# ...                                                    ...
# 1099999  Farmers Branch Shopping Center, 12895 Josey Ln...
# 1100000  Domino's Pizza, 9432 Natural Bridge Rd, Berkel...
# 1100001  Bullseye Shooting Range, 1455 N Terrace Dr, Wi...
# 1100002      Cha Spa, 2817 Main St, Santa Monica, CA 90405
# 1100003  Clean Touch Carpet Services, 702 W Mary Jane D...
#
#                                        gmap_id  \
# 0        0x88f16e41928ff687:0x883dad4fd048e8f8
# 1        0x80c2c98c0e3c16fd:0x29ec8a728764fdf9
# 2        0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 3         0x80c2c89923b27a41:0x32041559418d447
# 4        0x80c2c632f933b073:0xc31785961fe826a6
# ...                                        ...
# 1099999  0x864c27a6047a10e1:0xcd332f4713cf5a6a
# 1100000  0x87df34327dfbb649:0x7dc858dab8b30533
# 1100001  0x87bae320f4d7a9d1:0x24b5e3218e1d1549
# 1100002  0x80c2bad224faa469:0x1d564aa010920e46
# 1100003  0x86454b77ee9aed15:0x607937f639e48494
#
#                                                description   latitude  \
# 0                                                     None  32.388300
# 1                                                     None  34.018891
# 2                                                     None  34.058092
# 3                                                     None  34.023669
# 4                                                     None  34.036694
# ...                                                    ...        ...
# 1099999                                               None  32.923175
# 1100000  Delivery/carryout chain offering a wide range ...  38.725495
# 1100001                                               None  37.709828
# 1100002                                               None  33.999850
# 1100003                                               None  31.109170
#
#           longitude                                           category  \
# 0        -83.357100                                         [Pharmacy]
# 1       -118.215290                                 [Textile exporter]
# 2       -118.292130                                [Korean restaurant]
# 3       -118.232930                                     [Fabric store]
# 4       -118.249421                                     [Fabric store]
# ...             ...                                                ...
# 1099999  -96.882246                                    [Shopping mall]
# 1100000  -90.339572  [Pizza delivery, Delivery Restaurant, Takeout ...
# 1100001  -97.284202                         [Shooting range, Gun shop]
# 1100002 -118.481183  [Day spa, Facial spa, Massage therapist, Nail ...
# 1100003  -97.742610                          [Carpet cleaning service]
#
#          avg_rating  num_of_reviews price  \
# 0               4.9              16  None
# 1               4.5               6  None
# 2               4.4              18  None
# 3               3.3               6  None
# 4               4.3               7  None
# ...             ...             ...   ...
# 1099999         4.0             424  None
# 1100000         3.1             268     $
# 1100001         4.5             194  None
# 1100002         3.7              24  None
# 1100003         5.0             498  None
#
#                                                      hours  \
# 0        [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...
# 1                                                     None
# 2        [[Thursday, 6:30AM–6PM], [Friday, 6:30AM–6PM],...
# 3        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 4        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# ...                                                    ...
# 1099999                                               None
# 1100000  [[Friday, 10:30AM–1AM], [Saturday, 10:30AM–1AM...
# 1100001  [[Friday, 10AM–7PM], [Saturday, 10AM–6PM], [Su...
# 1100002  [[Friday, 10AM–10PM], [Saturday, 10AM–10PM], [...
# 1100003  [[Friday, 8AM–7PM], [Saturday, 8AM–7PM], [Sund...
#
#                                                       MISC  \
# 0        {'Service options': ['In-store shopping', 'Sam...
# 1                                                     None
# 2        {'Service options': ['Takeout', 'Dine-in', 'De...
# 3        {'Service options': ['In-store shopping'], 'Pa...
# 4                 {'Service options': ['In-store pickup']}
# ...                                                    ...
# 1099999  {'Service options': ['In-store shopping'], 'Ac...
# 1100000  {'Service options': ['Curbside pickup', 'No-co...
# 1100001  {'Accessibility': ['Wheelchair-accessible car ...
# 1100002  {'Accessibility': ['Wheelchair accessible entr...
# 1100003                                               None
#
#                            state  \
# 0              Open ⋅ Closes 6PM
# 1                       Open now
# 2              Open ⋅ Closes 6PM
# 3              Open ⋅ Closes 5PM
# 4              Open ⋅ Closes 5PM
# ...                          ...
# 1099999                     None
# 1100000        Open ⋅ Closes 1AM
# 1100001  Closed ⋅ Opens 10AM Sat
# 1100002       Open ⋅ Closes 10PM
# 1100003   Closed ⋅ Opens 8AM Sat
#
#                                           relative_results  \
# 0        [0x88f16e41929435cf:0x5b2532a2885e9ef6, 0x88f1...
# 1        [0x80c2c624136ea88b:0xb0315367ed448771, 0x80c2...
# 2        [0x80c2c78249aba68f:0x35bf16ce61be751d, 0x80c2...
# 3        [0x80c2c8811477253f:0x23a8a492df1918f7, 0x80c2...
# 4        [0x80c2c62c496083d1:0xdefa11317fe870a1, 0x80c2...
# ...                                                    ...
# 1099999  [0x864c20e52627ece5:0xc7284cab5500e6a5, 0x864c...
# 1100000  [0x87df35c8677a573f:0x3e7434f76833545d, 0x87df...
# 1100001  [0x87bae1127f210379:0x8df4dfd92ed2469, 0x87bae...
# 1100002  [0x80c2bad235832921:0xb12e61cb436a044c, 0x80c2...
# 1100003  [0x86454c07a715ce19:0x58d4eb6db27a6bfb, 0x865a...
#
#                                                        url
# 0        https://www.google.com/maps/place//data=!4m2!3...
# 1        https://www.google.com/maps/place//data=!4m2!3...
# 2        https://www.google.com/maps/place//data=!4m2!3...
# 3        https://www.google.com/maps/place//data=!4m2!3...
# 4        https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 1099999  https://www.google.com/maps/place//data=!4m2!3...
# 1100000  https://www.google.com/maps/place//data=!4m2!3...
# 1100001  https://www.google.com/maps/place//data=!4m2!3...
# 1100002  https://www.google.com/maps/place//data=!4m2!3...
# 1100003  https://www.google.com/maps/place//data=!4m2!3...
#
# [1100004 rows x 15 columns]

# %% [markdown]
# Verifico la existencia de nulos y tipos de datos

# %%
herramientas.verifica_tipo_y_nulos(df_sitios)
# Out:
#         nombre_campo                            tipo_datos  no_nulos_%  \
# 0               name   [<class 'str'>, <class 'NoneType'>]      100.00
# 1            address   [<class 'str'>, <class 'NoneType'>]       97.30
# 2            gmap_id                       [<class 'str'>]      100.00
# 3        description   [<class 'NoneType'>, <class 'str'>]        7.99
# 4           latitude                     [<class 'float'>]      100.00
# 5          longitude                     [<class 'float'>]      100.00
# 6           category  [<class 'list'>, <class 'NoneType'>]       99.41
# 7         avg_rating                     [<class 'float'>]      100.00
# 8     num_of_reviews                       [<class 'int'>]      100.00
# 9              price   [<class 'NoneType'>, <class 'str'>]        8.63
# 10             hours  [<class 'list'>, <class 'NoneType'>]       73.82
# 11              MISC  [<class 'dict'>, <class 'NoneType'>]       76.75
# 12             state   [<class 'str'>, <class 'NoneType'>]       75.10
# 13  relative_results  [<class 'list'>, <class 'NoneType'>]       90.15
# 14               url                       [<class 'str'>]      100.00
#
#     nulos_%    nulos
# 0      0.00       15
# 1      2.70    29672
# 2      0.00        0
# 3     92.01  1012128
# 4      0.00        0
# 5      0.00        0
# 6      0.59     6446
# 7      0.00        0
# 8      0.00        0
# 9     91.37  1005075
# 10    26.18   287946
# 11    23.25   255703
# 12    24.90   273908
# 13     9.85   108357
# 14     0.00        0

# %% [markdown]
# - ***Filtramos el metadata de sitios, con el estado de California***

# %%
# Filtrar los registros de df_sitios que tienen el mismo 'gmap_id' que los de California
df_sitios_california = df_sitios[df_sitios['gmap_id'].isin(df_california_concat['gmap_id'])].copy()

# Agregar la nueva columna 'California' al nuevo DataFrame
df_sitios_california['state'] = 'California'

#Observamos los cambios realizados
df_sitios_california
# Out:
#                                              name  \
# 2                                    San Soo Dang
# 4                                Nobel Textile Co
# 5                   Matrix International Textiles
# 6                                    Vons Chicken
# 13       Black Tie Ski Rental Delivery of Mammoth
# ...                                           ...
# 1099934                               Luna's Cafe
# 1099937                                  Rite Aid
# 1099939                                  Rite Aid
# 1099942                               Foot Locker
# 1099952                                    Subway
#
#                                                    address  \
# 2        San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 4        Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# 5        Matrix International Textiles, 1363 S Bonnie B...
# 6        Vons Chicken, 12740 La Mirada Blvd, La Mirada,...
# 13       Black Tie Ski Rental Delivery of Mammoth, 501 ...
# ...                                                    ...
# 1099934  Luna's Cafe, 917 S Sycamore St, Santa Ana, CA ...
# 1099937       Rite Aid, 111 N Main St, Santa Ana, CA 92701
# 1099939  Rite Aid, 1610 San Miguel Dr, Newport Beach, C...
# 1099942  Foot Locker, 3451 S Dogwood Rd Space 1464, El ...
# 1099952  Subway, 1753 N 1st St Suite 20, San Jose, CA 9...
#
#                                        gmap_id  \
# 2        0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 4        0x80c2c632f933b073:0xc31785961fe826a6
# 5        0x80c2cf163db6bc89:0x219484e2edbcfa41
# 6        0x80dd2b4c8555edb7:0xfc33d65c4bdbef42
# 13       0x80960c29f2e3bf29:0x4b291f0d275a5699
# ...                                        ...
# 1099934  0x80dcd91a30eeb005:0xda3db9bb93ef4937
# 1099937  0x80dcd9061788585b:0x7cd0f908a7ac6ebc
# 1099939   0x80dce09192e6cb4b:0xbf8840399a120ac
# 1099942  0x80d7668dc9ac1f59:0x56084e12bcd29e45
# 1099952  0x808fcb92d418608f:0xea0beaff05810c29
#
#                                                description   latitude  \
# 2                                                     None  34.058092
# 4                                                     None  34.036694
# 5                                                     None  34.015505
# 6                                                     None  33.916402
# 13                                                    None  37.638754
# ...                                                    ...        ...
# 1099934                                               None  33.734955
# 1099937                                               None  33.745985
# 1099939                                               None  33.611160
# 1099942  Retail chain with brand-name athletic shoes, c...  32.762143
# 1099952  Casual counter-serve chain for build-your-own ...  37.370730
#
#           longitude                                           category  \
# 2       -118.292130                                [Korean restaurant]
# 4       -118.249421                                     [Fabric store]
# 5       -118.181839                                     [Fabric store]
# 6       -118.010855                                       [Restaurant]
# 13      -118.966055     [Ski rental service, Snowboard rental service]
# ...             ...                                                ...
# 1099934 -117.868623                                             [Cafe]
# 1099937 -117.867039  [Drug store, Beauty supply store, Convenience ...
# 1099939 -117.864227  [Drug store, Beauty supply store, Convenience ...
# 1099942 -115.530845  [Shoe store, Clothing store, Fashion accessori...
# 1099952 -121.916823  [Sandwich shop, Caterer, Fast food restaurant,...
#
#          avg_rating  num_of_reviews price  \
# 2               4.4              18  None
# 4               4.3               7  None
# 5               3.5               6  None
# 6               4.5              18  None
# 13              5.0              34  None
# ...             ...             ...   ...
# 1099934         4.5              38  None
# 1099937         2.7              45    $$
# 1099939         2.8              15    $$
# 1099942         4.5              47    $$
# 1099952         3.7              74     $
#
#                                                      hours  \
# 2        [[Thursday, 6:30AM–6PM], [Friday, 6:30AM–6PM],...
# 4        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 5        [[Thursday, 8:30AM–5:30PM], [Friday, 8:30AM–5:...
# 6        [[Thursday, 11AM–9:30PM], [Friday, 11AM–9:30PM...
# 13       [[Thursday, 8AM–5PM], [Friday, 8AM–5PM], [Satu...
# ...                                                    ...
# 1099934  [[Friday, 9AM–6PM], [Saturday, 9AM–6PM], [Sund...
# 1099937  [[Friday, 7AM–10PM], [Saturday, 7AM–10PM], [Su...
# 1099939  [[Friday, 7AM–10PM], [Saturday, 7AM–10PM], [Su...
# 1099942  [[Friday, 11AM–8PM], [Saturday, 11AM–8PM], [Su...
# 1099952  [[Friday, 9AM–8PM], [Saturday, 10AM–7PM], [Sun...
#
#                                                       MISC       state  \
# 2        {'Service options': ['Takeout', 'Dine-in', 'De...  California
# 4                 {'Service options': ['In-store pickup']}  California
# 5        {'Accessibility': ['Wheelchair accessible entr...  California
# 6        {'Service options': ['Outdoor seating', 'Curbs...  California
# 13       {'Accessibility': ['Wheelchair accessible entr...  California
# ...                                                    ...         ...
# 1099934  {'Service options': ['Takeout', 'Dine-in', 'De...  California
# 1099937  {'Service options': ['Online care', 'Delivery'...  California
# 1099939  {'Service options': ['Online care', 'Delivery'...  California
# 1099942  {'Service options': ['In-store pickup', 'In-st...  California
# 1099952  {'Service options': ['Curbside pickup', 'Deliv...  California
#
#                                           relative_results  \
# 2        [0x80c2c78249aba68f:0x35bf16ce61be751d, 0x80c2...
# 4        [0x80c2c62c496083d1:0xdefa11317fe870a1, 0x80c2...
# 5        [0x80c2cf042a5d9561:0xd0024ad6f81f1335, 0x80c2...
# 6                                                     None
# 13       [0x80960dcd6ba76731:0x9a6875ced2f9228e, 0x8096...
# ...                                                    ...
# 1099934  [0x80dcd8dc37f120d5:0xf0ba6c061211747e, 0x80dc...
# 1099937  [0x80dcd90614ba5369:0xca770ba6d6747ad1, 0x80dc...
# 1099939  [0x80dce0f1292ab233:0xed63f9e051803b03, 0x80dc...
# 1099942  [0x80d7668dc6a3d5e5:0xd0ed7fdcca64668b, 0x80d7...
# 1099952  [0x808fcb7fecc4862d:0xbf7ef67abcb4fe13, 0x808f...
#
#                                                        url
# 2        https://www.google.com/maps/place//data=!4m2!3...
# 4        https://www.google.com/maps/place//data=!4m2!3...
# 5        https://www.google.com/maps/place//data=!4m2!3...
# 6        https://www.google.com/maps/place//data=!4m2!3...
# 13       https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 1099934  https://www.google.com/maps/place//data=!4m2!3...
# 1099937  https://www.google.com/maps/place//data=!4m2!3...
# 1099939  https://www.google.com/maps/place//data=!4m2!3...
# 1099942  https://www.google.com/maps/place//data=!4m2!3...
# 1099952  https://www.google.com/maps/place//data=!4m2!3...
#
# [30743 rows x 15 columns]

# %% [markdown]
# Verificamos la existencia de valores nulos y tipo de datos

# %%
herramientas.verifica_tipo_y_nulos(df_sitios_california)
# Out:
#         nombre_campo                            tipo_datos  no_nulos_%  \
# 0               name   [<class 'str'>, <class 'NoneType'>]      100.00
# 1            address   [<class 'str'>, <class 'NoneType'>]       99.43
# 2            gmap_id                       [<class 'str'>]      100.00
# 3        description   [<class 'NoneType'>, <class 'str'>]       14.82
# 4           latitude                     [<class 'float'>]      100.00
# 5          longitude                     [<class 'float'>]      100.00
# 6           category  [<class 'list'>, <class 'NoneType'>]       99.88
# 7         avg_rating                     [<class 'float'>]      100.00
# 8     num_of_reviews                       [<class 'int'>]      100.00
# 9              price   [<class 'NoneType'>, <class 'str'>]       14.24
# 10             hours  [<class 'list'>, <class 'NoneType'>]       87.20
# 11              MISC  [<class 'dict'>, <class 'NoneType'>]       90.43
# 12             state                       [<class 'str'>]      100.00
# 13  relative_results  [<class 'list'>, <class 'NoneType'>]       95.36
# 14               url                       [<class 'str'>]      100.00
#
#     nulos_%  nulos
# 0      0.00      1
# 1      0.57    174
# 2      0.00      0
# 3     85.18  26187
# 4      0.00      0
# 5      0.00      0
# 6      0.12     36
# 7      0.00      0
# 8      0.00      0
# 9     85.76  26366
# 10    12.80   3934
# 11     9.57   2943
# 12     0.00      0
# 13     4.64   1425
# 14     0.00      0

# %% [markdown]
# Eliminamos los nulos de la columna 'category'

# %%
# Eliminar filas con valores nulos en la columna 'category'
df_sitios_california = df_sitios_california.dropna(subset=['category'])

# %% [markdown]
# Verificamos los cambios realizados anteriormente

# %%
herramientas.verifica_tipo_y_nulos(df_sitios_california)
# Out:
#         nombre_campo                            tipo_datos  no_nulos_%  \
# 0               name   [<class 'str'>, <class 'NoneType'>]      100.00
# 1            address   [<class 'str'>, <class 'NoneType'>]       99.43
# 2            gmap_id                       [<class 'str'>]      100.00
# 3        description   [<class 'NoneType'>, <class 'str'>]       14.81
# 4           latitude                     [<class 'float'>]      100.00
# 5          longitude                     [<class 'float'>]      100.00
# 6           category                      [<class 'list'>]      100.00
# 7         avg_rating                     [<class 'float'>]      100.00
# 8     num_of_reviews                       [<class 'int'>]      100.00
# 9              price   [<class 'NoneType'>, <class 'str'>]       14.21
# 10             hours  [<class 'list'>, <class 'NoneType'>]       87.22
# 11              MISC  [<class 'dict'>, <class 'NoneType'>]       90.53
# 12             state                       [<class 'str'>]      100.00
# 13  relative_results  [<class 'list'>, <class 'NoneType'>]       95.37
# 14               url                       [<class 'str'>]      100.00
#
#     nulos_%  nulos
# 0      0.00      1
# 1      0.57    174
# 2      0.00      0
# 3     85.19  26159
# 4      0.00      0
# 5      0.00      0
# 6      0.00      0
# 7      0.00      0
# 8      0.00      0
# 9     85.79  26343
# 10    12.78   3923
# 11     9.47   2907
# 12     0.00      0
# 13     4.63   1421
# 14     0.00      0

# %% [markdown]
# - ***Filtramos el metadata de sitios, con el estado de Texas***

# %%
# Filtrar los registros de Mdf_sitios que tienen el mismo 'gmap_id' que los de Texas
df_sitios_texas = df_sitios[df_sitios['gmap_id'].isin(df_texas_concat['gmap_id'])].copy()

# Agregar la nueva columna 'Texas' al nuevo DataFrame
df_sitios_texas['state'] = 'Texas'

#Observamos los cambios realizados
df_sitios_texas
# Out:
#                                          name  \
# 35                           Walmart Pharmacy
# 39       Cricket Wireless Authorized Retailer
# 99                   Hunter's RV Park: Office
# 123                             Golden Castle
# 221             Women's Clinic of South Texas
# ...                                       ...
# 1099886                    Maserati of Austin
# 1099943                         J & M Exhaust
# 1099945                 A-1 Muffler & Welding
# 1099999        Farmers Branch Shopping Center
# 1100003           Clean Touch Carpet Services
#
#                                                    address  \
# 35        Walmart Pharmacy, 12220 FM 423, Frisco, TX 75033
# 39       Cricket Wireless Authorized Retailer, 2785 E E...
# 99       Hunter's RV Park: Office, 605 S Main St, Highl...
# 123        Golden Castle, 1906 E 12th St, Austin, TX 78702
# 221      Women's Clinic of South Texas, 3001 N 23rd St,...
# ...                                                    ...
# 1099886  Maserati of Austin, 12925 Pond Springs Rd, Aus...
# 1099943  J & M Exhaust, 7411 Boulevard 26, North Richla...
# 1099945  A-1 Muffler & Welding, 2130 Jacksboro Hwy, For...
# 1099999  Farmers Branch Shopping Center, 12895 Josey Ln...
# 1100003  Clean Touch Carpet Services, 702 W Mary Jane D...
#
#                                        gmap_id  \
# 35       0x864c3998b8d8dc83:0x57ffabe1e2322320
# 39        0x864c399793df5ee1:0x89754310c1a68fe
# 99       0x863f589f655fa251:0xb329697cb9f39b66
# 123      0x8644b59b8fe872e5:0x5e638876caa84cc3
# 221      0x8665a6de4fed9c07:0xd8e859cdc30d7281
# ...                                        ...
# 1099886  0x8644cd26613306b9:0x4ad8e79d7ac54ccb
# 1099943  0x864e785519c45361:0xa48c3a2ca3bec550
# 1099945  0x864e747284b57d61:0xf80ed757e2bf54d4
# 1099999  0x864c27a6047a10e1:0xcd332f4713cf5a6a
# 1100003  0x86454b77ee9aed15:0x607937f639e48494
#
#                                                description   latitude  \
# 35                                                    None  33.179867
# 39       Wireless provider offering prepaid mobile phon...  33.178885
# 99                                                    None  29.808913
# 123                                                   None  30.273985
# 221                                                   None  26.233672
# ...                                                    ...        ...
# 1099886                                               None  30.439371
# 1099943                                               None  32.827175
# 1099945                                               None  32.782700
# 1099999                                               None  32.923175
# 1100003                                               None  31.109170
#
#          longitude                                           category  \
# 35      -96.883691  [Pharmacy, Drug store, Medical supply store, V...
# 39      -96.889600                                 [Cell phone store]
# 99      -95.056543                                       [Campground]
# 123     -97.719563                                       [Restaurant]
# 221     -98.241197                                   [Medical clinic]
# ...            ...                                                ...
# 1099886 -97.771432  [Maserati dealer, Car dealer, Car finance and ...
# 1099943 -97.224205                                     [Muffler shop]
# 1099945 -97.374804  [Muffler shop, Auto repair shop, Metal fabrica...
# 1099999 -96.882246                                    [Shopping mall]
# 1100003 -97.742610                          [Carpet cleaning service]
#
#          avg_rating  num_of_reviews price  \
# 35              3.3              24     $
# 39              4.5              73  None
# 99              4.4              28  None
# 123             4.5               8  None
# 221             2.8              28  None
# ...             ...             ...   ...
# 1099886         4.0              88  None
# 1099943         4.0              78  None
# 1099945         4.8              46  None
# 1099999         4.0             424  None
# 1100003         5.0             498  None
#
#                                                      hours  \
# 35       [[Thursday, 9AM–9PM], [Friday, 9AM–9PM], [Satu...
# 39       [[Thursday, 10AM–7PM], [Friday, 10AM–7PM], [Sa...
# 99                                                    None
# 123      [[Thursday, 5PM–12AM], [Friday, 5PM–12AM], [Sa...
# 221      [[Thursday, 7:30AM–6:30PM], [Friday, 7:30AM–5:...
# ...                                                    ...
# 1099886  [[Friday, 9AM–6PM], [Saturday, 9AM–5PM], [Sund...
# 1099943  [[Friday, 9AM–5PM], [Saturday, 9AM–5PM], [Sund...
# 1099945  [[Friday, 8AM–5PM], [Saturday, 9AM–3PM], [Sund...
# 1099999                                               None
# 1100003  [[Friday, 8AM–7PM], [Saturday, 8AM–7PM], [Sund...
#
#                                                       MISC  state  \
# 35       {'Service options': ['Curbside pickup', 'In-st...  Texas
# 39       {'Service options': ['In-store shopping', 'Del...  Texas
# 99       {'Accessibility': ['Wheelchair accessible entr...  Texas
# 123      {'Service options': ['Delivery', 'Takeout', 'D...  Texas
# 221      {'Accessibility': ['Wheelchair accessible entr...  Texas
# ...                                                    ...    ...
# 1099886  {'Service options': ['In-store shopping'], 'Ac...  Texas
# 1099943  {'Service options': ['In-store shopping', 'Del...  Texas
# 1099945  {'Service options': ['In-store pickup', 'In-st...  Texas
# 1099999  {'Service options': ['In-store shopping'], 'Ac...  Texas
# 1100003                                               None  Texas
#
#                                           relative_results  \
# 35       [0x864c3999b29e291f:0x2d364c05e88eec13, 0x864c...
# 39       [0x864c3999f2047cab:0x65d5180e6920725a, 0x864c...
# 99       [0x863f58af62e1e3b1:0x78314375b1ceb16, 0x8640a...
# 123                                                   None
# 221      [0x8665a13e873178fb:0xeb3aa6a6cef5b458, 0x8665...
# ...                                                    ...
# 1099886  [0x8644cd29114b1191:0x415e0d2875419846, 0x8644...
# 1099943  [0x864e769d516df8c9:0xb211a7192115962d, 0x864e...
# 1099945  [0x864e769d516df8c9:0xb211a7192115962d, 0x864e...
# 1099999  [0x864c20e52627ece5:0xc7284cab5500e6a5, 0x864c...
# 1100003  [0x86454c07a715ce19:0x58d4eb6db27a6bfb, 0x865a...
#
#                                                        url
# 35       https://www.google.com/maps/place//data=!4m2!3...
# 39       https://www.google.com/maps/place//data=!4m2!3...
# 99       https://www.google.com/maps/place//data=!4m2!3...
# 123      https://www.google.com/maps/place//data=!4m2!3...
# 221      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 1099886  https://www.google.com/maps/place//data=!4m2!3...
# 1099943  https://www.google.com/maps/place//data=!4m2!3...
# 1099945  https://www.google.com/maps/place//data=!4m2!3...
# 1099999  https://www.google.com/maps/place//data=!4m2!3...
# 1100003  https://www.google.com/maps/place//data=!4m2!3...
#
# [29437 rows x 15 columns]

# %% [markdown]
# Verificamos la existencia de valores nulos y tipo de datos

# %%
herramientas.verifica_tipo_y_nulos(df_sitios_texas)
# Out:
#         nombre_campo                            tipo_datos  no_nulos_%  \
# 0               name                       [<class 'str'>]      100.00
# 1            address   [<class 'str'>, <class 'NoneType'>]       98.74
# 2            gmap_id                       [<class 'str'>]      100.00
# 3        description   [<class 'NoneType'>, <class 'str'>]       11.58
# 4           latitude                     [<class 'float'>]      100.00
# 5          longitude                     [<class 'float'>]      100.00
# 6           category  [<class 'list'>, <class 'NoneType'>]       99.89
# 7         avg_rating                     [<class 'float'>]      100.00
# 8     num_of_reviews                       [<class 'int'>]      100.00
# 9              price   [<class 'str'>, <class 'NoneType'>]       10.97
# 10             hours  [<class 'list'>, <class 'NoneType'>]       87.32
# 11              MISC  [<class 'dict'>, <class 'NoneType'>]       88.17
# 12             state                       [<class 'str'>]      100.00
# 13  relative_results  [<class 'list'>, <class 'NoneType'>]       94.20
# 14               url                       [<class 'str'>]      100.00
#
#     nulos_%  nulos
# 0      0.00      0
# 1      1.26    371
# 2      0.00      0
# 3     88.42  26029
# 4      0.00      0
# 5      0.00      0
# 6      0.11     31
# 7      0.00      0
# 8      0.00      0
# 9     89.03  26207
# 10    12.68   3733
# 11    11.83   3481
# 12     0.00      0
# 13     5.80   1708
# 14     0.00      0

# %% [markdown]
# Eliminamos los nulos de la columna 'category'

# %%
# Eliminar filas con valores nulos en la columna 'category'
df_sitios_texas = df_sitios_texas.dropna(subset=['category'])

# %% [markdown]
# Verificamos los cambios realizados anteriormente

# %%
herramientas.verifica_tipo_y_nulos(df_sitios_texas)
# Out:
#         nombre_campo                            tipo_datos  no_nulos_%  \
# 0               name                       [<class 'str'>]      100.00
# 1            address   [<class 'str'>, <class 'NoneType'>]       98.74
# 2            gmap_id                       [<class 'str'>]      100.00
# 3        description   [<class 'NoneType'>, <class 'str'>]       11.58
# 4           latitude                     [<class 'float'>]      100.00
# 5          longitude                     [<class 'float'>]      100.00
# 6           category                      [<class 'list'>]      100.00
# 7         avg_rating                     [<class 'float'>]      100.00
# 8     num_of_reviews                       [<class 'int'>]      100.00
# 9              price   [<class 'str'>, <class 'NoneType'>]       10.96
# 10             hours  [<class 'list'>, <class 'NoneType'>]       87.36
# 11              MISC  [<class 'dict'>, <class 'NoneType'>]       88.27
# 12             state                       [<class 'str'>]      100.00
# 13  relative_results  [<class 'list'>, <class 'NoneType'>]       94.21
# 14               url                       [<class 'str'>]      100.00
#
#     nulos_%  nulos
# 0      0.00      0
# 1      1.26    371
# 2      0.00      0
# 3     88.42  26001
# 4      0.00      0
# 5      0.00      0
# 6      0.00      0
# 7      0.00      0
# 8      0.00      0
# 9     89.04  26182
# 10    12.64   3717
# 11    11.73   3450
# 12     0.00      0
# 13     5.79   1704
# 14     0.00      0

# %% [markdown]
# - ***Filtramos el metadata de sitios, con el estado de New York***

# %%
# Filtrar los registros de Mdf_sitios que tienen el mismo 'gmap_id' que los de New York
df_sitios_new_york = df_sitios[df_sitios['gmap_id'].isin(df_new_york_concat['gmap_id'])].copy()

# Agregar la nueva columna 'New York' al nuevo DataFrame
df_sitios_new_york['state'] = 'New York'

#Observamos los cambios realizados
df_sitios_new_york
# Out:
#                                                       name  \
# 59                                                T-Mobile
# 195                              Gillespie Chevrolet Parts
# 328                          Arcana Juventa Anti-Aging Spa
# 334                           Horizon Health Care Staffing
# 432      NYC Parking Manhattan Avenue. Garage Corporation.
# ...                                                    ...
# 1099746                Creek-N-Wood RV Park and Campground
# 1099747                          Absolute Automotive of Ny
# 1099751                       Michael Prouty Memorial Park
# 1099848                                        Cafe Booqoo
# 1099854                               Lida's Beauty Lounge
#
#                                                    address  \
# 59               T-Mobile, 3923 103rd St, Queens, NY 11368
# 195      Gillespie Chevrolet Parts, 128 Cayuga St, Unio...
# 328      Arcana Juventa Anti-Aging Spa, 14 Brighton 11t...
# 334      Horizon Health Care Staffing, 101 Ellis St # M...
# 432      NYC Parking Manhattan Avenue. Garage Corporati...
# ...                                                    ...
# 1099746  Creek-N-Wood RV Park and Campground, 2530 Whee...
# 1099747  Absolute Automotive of Ny, 2310 Walworth-Mario...
# 1099751  Michael Prouty Memorial Park, 2402-2474 NY-65,...
# 1099848      Cafe Booqoo, 478 Smith St, Brooklyn, NY 11231
# 1099854  Lida's Beauty Lounge, 2624 Broadway, New York,...
#
#                                        gmap_id description   latitude  \
# 59         0x89c25fc9494dce47:0x6d63c807b59a55        None  40.750146
# 195      0x89d0ba60bb7d710f:0x877e749ac7f9304a        None  42.840487
# 328      0x89c244688b7609cd:0x205e2d8d173dd35e        None  40.582130
# 334      0x89c3b5606048fd35:0x372ca4b707b21213        None  40.517670
# 432      0x89c2f6146dd4b907:0x5a6b44a7f6b8a76c        None  40.807305
# ...                                        ...         ...        ...
# 1099746  0x89d13ad30c7fcaff:0x3c01448f5da558dd        None  42.906084
# 1099747  0x89d6d41470c5dbf5:0x66461848781795d3        None  43.138831
# 1099751  0x89d1388d4acc026f:0x30a872bfd0a4679d        None  42.908991
# 1099848  0x89c25af6e18e56a5:0x9b38fce3dbd88098        None  40.674726
# 1099854  0x89c2f768aac90c8b:0x3decd1160a13170b        None  40.796580
#
#          longitude                                           category  \
# 59      -73.862536  [Cell phone store, Electronic parts supplier, ...
# 195     -76.692377                                 [Auto parts store]
# 328     -73.956333                       [Spa, Waterproofing company]
# 334     -74.242485                                [Employment agency]
# 432     -73.954636                                   [Parking garage]
# ...            ...                                                ...
# 1099746 -77.380880                                       [Campground]
# 1099747 -77.268383                                 [Auto repair shop]
# 1099751 -77.539035                                             [Park]
# 1099848 -73.997918  [Creole restaurant, Breakfast restaurant, Cafe...
# 1099854 -73.969919                           [Hair salon, Nail salon]
#
#          avg_rating  num_of_reviews price  \
# 59              3.5              95    $$
# 195             4.6              18  None
# 328             4.1              15  None
# 334             3.9               8  None
# 432             3.7               8  None
# ...             ...             ...   ...
# 1099746         4.5              58  None
# 1099747         4.9              45  None
# 1099751         4.1              16  None
# 1099848         4.5              68  None
# 1099854         4.8              38  None
#
#                                                      hours  \
# 59       [[Thursday, 10AM–8PM], [Friday, 10AM–8PM], [Sa...
# 195      [[Thursday, 7:30AM–8PM], [Friday, 7:30AM–5PM],...
# 328      [[Thursday, 10AM–8PM], [Friday, 10AM–8PM], [Sa...
# 334                                                   None
# 432      [[Thursday, Open 24 hours], [Friday, Open 24 h...
# ...                                                    ...
# 1099746                                               None
# 1099747  [[Friday, 8AM–6PM], [Saturday, Closed], [Sunda...
# 1099751  [[Friday, 8AM–6PM], [Saturday, 8AM–6PM], [Sund...
# 1099848  [[Friday, 11AM–8PM], [Saturday, 9AM–4PM], [Sun...
# 1099854  [[Friday, 9AM–8PM], [Saturday, 9AM–8PM], [Sund...
#
#                                                       MISC     state  \
# 59       {'Service options': ['In-store shopping', 'Del...  New York
# 195      {'Service options': ['In-store shopping'], 'Ac...  New York
# 328                                                   None  New York
# 334      {'Health & safety': ['Appointment required'], ...  New York
# 432      {'Accessibility': ['Wheelchair accessible entr...  New York
# ...                                                    ...       ...
# 1099746  {'Accessibility': ['Wheelchair accessible entr...  New York
# 1099747  {'Accessibility': ['Wheelchair accessible entr...  New York
# 1099751  {'Accessibility': ['Wheelchair accessible entr...  New York
# 1099848  {'Service options': ['Takeout', 'Delivery'], '...  New York
# 1099854  {'From the business': ['Identifies as women-le...  New York
#
#                                           relative_results  \
# 59       [0x89c25fc7a91c609f:0xb103d6a261373fd, 0x89c25...
# 195      [0x89d0ab78eb57aca9:0x3a78b7d92d2e3950, 0x89d0...
# 328      [0x89c2446bdf00743d:0x1a016c5e3c603c88, 0x89c2...
# 334      [0x89c24e8123a04bdf:0x647442f3bc28496, 0x89c24...
# 432      [0x89c2f613135dfba3:0xe185cc5d2b02df0f, 0x89c2...
# ...                                                    ...
# 1099746  [0x89d13d78ddf709e5:0x80dc7df9525a6103, 0x873b...
# 1099747  [0x89d6d413ac3b37c9:0xe8f4ed0862cd4c0a, 0x89d6...
# 1099751  [0x89d13ba56ebef6a1:0x196f02728d220a25, 0x89d1...
# 1099848  [0x89c25a4e53443397:0xecc6f06f74f11410, 0x89c2...
# 1099854  [0x89c2f6260bfa97d5:0x9183d760186c18cd, 0x89c2...
#
#                                                        url
# 59       https://www.google.com/maps/place//data=!4m2!3...
# 195      https://www.google.com/maps/place//data=!4m2!3...
# 328      https://www.google.com/maps/place//data=!4m2!3...
# 334      https://www.google.com/maps/place//data=!4m2!3...
# 432      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 1099746  https://www.google.com/maps/place//data=!4m2!3...
# 1099747  https://www.google.com/maps/place//data=!4m2!3...
# 1099751  https://www.google.com/maps/place//data=!4m2!3...
# 1099848  https://www.google.com/maps/place//data=!4m2!3...
# 1099854  https://www.google.com/maps/place//data=!4m2!3...
#
# [25818 rows x 15 columns]

# %% [markdown]
# Verificamos la existencia de valores nulos y tipo de datos

# %%
herramientas.verifica_tipo_y_nulos(df_sitios_new_york)
# Out:
#         nombre_campo                            tipo_datos  no_nulos_%  \
# 0               name                       [<class 'str'>]      100.00
# 1            address   [<class 'str'>, <class 'NoneType'>]       99.61
# 2            gmap_id                       [<class 'str'>]      100.00
# 3        description   [<class 'NoneType'>, <class 'str'>]       15.47
# 4           latitude                     [<class 'float'>]      100.00
# 5          longitude                     [<class 'float'>]      100.00
# 6           category  [<class 'list'>, <class 'NoneType'>]       99.94
# 7         avg_rating                     [<class 'float'>]      100.00
# 8     num_of_reviews                       [<class 'int'>]      100.00
# 9              price   [<class 'str'>, <class 'NoneType'>]       18.58
# 10             hours  [<class 'list'>, <class 'NoneType'>]       85.96
# 11              MISC  [<class 'dict'>, <class 'NoneType'>]       88.42
# 12             state                       [<class 'str'>]      100.00
# 13  relative_results  [<class 'list'>, <class 'NoneType'>]       95.65
# 14               url                       [<class 'str'>]      100.00
#
#     nulos_%  nulos
# 0      0.00      0
# 1      0.39    100
# 2      0.00      0
# 3     84.53  21824
# 4      0.00      0
# 5      0.00      0
# 6      0.06     16
# 7      0.00      0
# 8      0.00      0
# 9     81.42  21021
# 10    14.04   3624
# 11    11.58   2990
# 12     0.00      0
# 13     4.35   1124
# 14     0.00      0

# %% [markdown]
# Eliminamos los nulos de la columna 'category'

# %%
# Eliminar filas con valores nulos en la columna 'category'
df_sitios_new_york = df_sitios_new_york.dropna(subset=['category'])

# %% [markdown]
# Verificamos los cambios realizados anteriormente

# %%
herramientas.verifica_tipo_y_nulos(df_sitios_new_york)
# Out:
#         nombre_campo                            tipo_datos  no_nulos_%  \
# 0               name                       [<class 'str'>]      100.00
# 1            address   [<class 'str'>, <class 'NoneType'>]       99.61
# 2            gmap_id                       [<class 'str'>]      100.00
# 3        description   [<class 'NoneType'>, <class 'str'>]       15.46
# 4           latitude                     [<class 'float'>]      100.00
# 5          longitude                     [<class 'float'>]      100.00
# 6           category                      [<class 'list'>]      100.00
# 7         avg_rating                     [<class 'float'>]      100.00
# 8     num_of_reviews                       [<class 'int'>]      100.00
# 9              price   [<class 'str'>, <class 'NoneType'>]       18.58
# 10             hours  [<class 'list'>, <class 'NoneType'>]       85.99
# 11              MISC  [<class 'dict'>, <class 'NoneType'>]       88.47
# 12             state                       [<class 'str'>]      100.00
# 13  relative_results  [<class 'list'>, <class 'NoneType'>]       95.66
# 14               url                       [<class 'str'>]      100.00
#
#     nulos_%  nulos
# 0      0.00      0
# 1      0.39    100
# 2      0.00      0
# 3     84.54  21812
# 4      0.00      0
# 5      0.00      0
# 6      0.00      0
# 7      0.00      0
# 8      0.00      0
# 9     81.42  21009
# 10    14.01   3616
# 11    11.53   2974
# 12     0.00      0
# 13     4.34   1119
# 14     0.00      0

# %% [markdown]
# - ***Filtramos el metadata de sitios, con el estado de Florida***

# %%
# Filtrar los registros de Mdf_sitios que tienen el mismo 'gmap_id' que los de Florida
df_sitios_florida = df_sitios[df_sitios['gmap_id'].isin(df_florida_concat['gmap_id'])].copy()

# Agregar la nueva columna 'Florida' al nuevo DataFrame
df_sitios_florida['state'] = 'Florida'

#Observamos los cambios realizados
df_sitios_florida
# Out:
#                                name  \
# 105               Brian Shaheen, MD
# 117                    Mail Station
# 118                  APC Pediatrics
# 119              Infinia Accounting
# 120      Baker Distributing Company
# ...                             ...
# 1099837                  Smoke Shop
# 1099838         Venci's Barber Shop
# 1099839        Oviedo Little League
# 1099841                   CosmoProf
# 1099853         Kiwi Camera Service
#
#                                                    address  \
# 105      Brian Shaheen, MD, 2421 Thomas Dr, Panama City...
# 117      Mail Station, 8466 Lockwood Ridge Rd, Sarasota...
# 118      APC Pediatrics, 5255 Office Park Blvd 110 & 11...
# 119      Infinia Accounting, 555 W. Granada Blvd Ste Bl...
# 120      Baker Distributing Company, 7810 25th Ct E #11...
# ...                                                    ...
# 1099837  Smoke Shop, 5275 Red Bug Lake Rd #125, Winter ...
# 1099838  Venci's Barber Shop, 1325 W Broadway St, Ovied...
# 1099839  Oviedo Little League, 275 King St, Oviedo, FL ...
# 1099841  CosmoProf, 4257 W Lake Mary Blvd #10, Lake Mar...
# 1099853  Kiwi Camera Service, 542 Virginia Dr, Orlando,...
#
#                                        gmap_id description   latitude  \
# 105      0x8893863ea87bd5dd:0x9383ebf973e74abb        None  30.159982
# 117      0x88c33f1c8e1f99a3:0x99b22c5bd258b3a7        None  27.389683
# 118      0x88c33c2935058dd3:0xb888c702ecf5aef6        None  27.448302
# 119      0x88d908b8c02dc3bb:0xea94b1fb47b68ef6        None  29.280410
# 120      0x88c33fb303dc8e69:0x3485e731f1a704f8        None  27.401269
# ...                                        ...         ...        ...
# 1099837  0x88e76eeb288b3547:0x1a15780ed1dd82e3        None  28.647043
# 1099838  0x88e76961865270e9:0xbe67cb393b44261f        None  28.665168
# 1099839  0x88e769038bdd946d:0x915dab8e50516a3d        None  28.672274
# 1099841  0x88e772bad61b7dd3:0x3f42bbf4a63267b0        None  28.754376
# 1099853  0x88e7707a3e52a995:0x2f5ce7422c76d27e        None  28.563873
#
#          longitude                                           category  \
# 105     -85.752277  [Family practice physician, General practitioner]
# 117     -82.508387  [Mailing service, Courier service, Fax service...
# 118     -82.510850        [Pediatrician, Children's hospital, Doctor]
# 119     -81.071481  [Tax preparation service, Accountant, Payroll ...
# 120     -82.532346  [Air conditioning system supplier, Air filter ...
# ...            ...                                                ...
# 1099837 -81.276647                         [Tobacco shop, Cigar shop]
# 1099838 -81.224895                                      [Barber shop]
# 1099839 -81.215889               [Little league club, Sports complex]
# 1099841 -81.351337                              [Beauty supply store]
# 1099853 -81.370078                               [Camera repair shop]
#
#          avg_rating  num_of_reviews price  \
# 105             4.2              18  None
# 117             3.4              28  None
# 118             4.2              34  None
# 119             5.0              13  None
# 120             4.3               8  None
# ...             ...             ...   ...
# 1099837         4.4              78  None
# 1099838         4.8              64  None
# 1099839         4.4              48  None
# 1099841         4.4              37  None
# 1099853         5.0             128  None
#
#                                                      hours  \
# 105      [[Thursday, 8AM–5PM], [Friday, 8AM–5PM], [Satu...
# 117      [[Thursday, 8AM–5PM], [Friday, 8AM–5PM], [Satu...
# 118      [[Thursday, 8AM–5PM], [Friday, 8AM–5PM], [Satu...
# 119      [[Thursday, 10AM–5PM], [Friday, 10AM–4PM], [Sa...
# 120      [[Thursday, 7:30AM–5PM], [Friday, 7:30AM–5PM],...
# ...                                                    ...
# 1099837  [[Friday, 11AM–9:30PM], [Saturday, 11AM–9:30PM...
# 1099838  [[Friday, 8:30AM–3PM], [Saturday, 8AM–2PM], [S...
# 1099839  [[Friday, 5–9PM], [Saturday, 8:30AM–3PM], [Sun...
# 1099841  [[Friday, 8AM–6PM], [Saturday, 8AM–4PM], [Sund...
# 1099853  [[Friday, 11AM–6PM], [Saturday, 11AM–4PM], [Su...
#
#                                                       MISC    state  \
# 105      {'Service options': ['Online care'], 'Accessib...  Florida
# 117      {'Accessibility': ['Wheelchair accessible entr...  Florida
# 118      {'Service options': ['Online care'], 'Health &...  Florida
# 119      {'Accessibility': ['Wheelchair accessible entr...  Florida
# 120      {'Accessibility': ['Wheelchair accessible entr...  Florida
# ...                                                    ...      ...
# 1099837  {'Service options': ['In-store shopping', 'Del...  Florida
# 1099838  {'Accessibility': ['Wheelchair accessible entr...  Florida
# 1099839  {'Accessibility': ['Wheelchair accessible entr...  Florida
# 1099841  {'Service options': ['Curbside pickup', 'Deliv...  Florida
# 1099853                                               None  Florida
#
#                                           relative_results  \
# 105      [0x88938ebfbd53f9c5:0xf6e52004f37523c8, 0x8893...
# 117      [0x88c3475a64b98c03:0xe8de19a19dae1b2c, 0x88c3...
# 118      [0x88c33e113c201abb:0x49ef8b29737f8773, 0x88c3...
# 119      [0x88e6dc9fd184eed9:0x81252448cc728aa8, 0x88e6...
# 120      [0x88c33e46cf5434ad:0x8772f525f32cc2d2, 0x88c3...
# ...                                                    ...
# 1099837  [0x88e76e3c25fc6b5d:0x43d6684d268ada2e, 0x88e7...
# 1099838  [0x88e769f68d97c221:0xdc735caf0e5c146f, 0x88e7...
# 1099839  [0x88e76bd4d42d834f:0xf0d38820c232deb1, 0x88e7...
# 1099841  [0x88e772b90fe0a9a1:0x3428036853668172, 0x88e7...
# 1099853  [0x88e76a2b4e705b0f:0x80fa922aa501bb87, 0x88e7...
#
#                                                        url
# 105      https://www.google.com/maps/place//data=!4m2!3...
# 117      https://www.google.com/maps/place//data=!4m2!3...
# 118      https://www.google.com/maps/place//data=!4m2!3...
# 119      https://www.google.com/maps/place//data=!4m2!3...
# 120      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 1099837  https://www.google.com/maps/place//data=!4m2!3...
# 1099838  https://www.google.com/maps/place//data=!4m2!3...
# 1099839  https://www.google.com/maps/place//data=!4m2!3...
# 1099841  https://www.google.com/maps/place//data=!4m2!3...
# 1099853  https://www.google.com/maps/place//data=!4m2!3...
#
# [22243 rows x 15 columns]

# %% [markdown]
# Verificamos la existencia de valores nulos y tipo de datos

# %%
herramientas.verifica_tipo_y_nulos(df_sitios_florida)
# Out:
#         nombre_campo                            tipo_datos  no_nulos_%  \
# 0               name                       [<class 'str'>]      100.00
# 1            address   [<class 'str'>, <class 'NoneType'>]       98.13
# 2            gmap_id                       [<class 'str'>]      100.00
# 3        description   [<class 'NoneType'>, <class 'str'>]       11.03
# 4           latitude                     [<class 'float'>]      100.00
# 5          longitude                     [<class 'float'>]      100.00
# 6           category  [<class 'list'>, <class 'NoneType'>]       99.95
# 7         avg_rating                     [<class 'float'>]      100.00
# 8     num_of_reviews                       [<class 'int'>]      100.00
# 9              price   [<class 'NoneType'>, <class 'str'>]       10.38
# 10             hours  [<class 'list'>, <class 'NoneType'>]       86.89
# 11              MISC  [<class 'dict'>, <class 'NoneType'>]       88.58
# 12             state                       [<class 'str'>]      100.00
# 13  relative_results  [<class 'list'>, <class 'NoneType'>]       94.46
# 14               url                       [<class 'str'>]      100.00
#
#     nulos_%  nulos
# 0      0.00      0
# 1      1.87    417
# 2      0.00      0
# 3     88.97  19790
# 4      0.00      0
# 5      0.00      0
# 6      0.05     12
# 7      0.00      0
# 8      0.00      0
# 9     89.62  19935
# 10    13.11   2917
# 11    11.42   2541
# 12     0.00      0
# 13     5.54   1232
# 14     0.00      0

# %% [markdown]
# - ***Filtramos el metadata de sitios, con el estado de Illinois***

# %%
# Filtrar los registros de Mdf_sitios que tienen el mismo 'gmap_id' que los de Illinois
df_sitios_illinois = df_sitios[df_sitios['gmap_id'].isin(df_illinois_concat['gmap_id'])].copy()

# Agregar la nueva columna 'Illinois' al nuevo DataFrame
df_sitios_illinois['state'] = 'Illinois'

#Observamos los cambios realizados
df_sitios_illinois
# Out:
#                                                       name  \
# 124                                          The Toy House
# 125                                           ROYAL LIQUOR
# 135                             Newton, IL Chizevsky Field
# 138                                      Camp Walter Scott
# 526                                   Honda Service Center
# ...                                                    ...
# 1099759                                          Dry Goods
# 1099779                                Williams Automotive
# 1099896  Doctors of Physical Therapy, merged with Colle...
# 1099899                                          K B CITGO
# 1099941                                          Starbucks
#
#                                                    address  \
# 124      The Toy House, 10 E Main St #105, East Dundee,...
# 125      ROYAL LIQUOR, 26W211 Geneva Rd, Wheaton, IL 60187
# 135      Newton, IL Chizevsky Field, W Decatur St, Newt...
# 138      Camp Walter Scott, 15290 E 300th Ave, Dieteric...
# 526      Honda Service Center, 1111 N Clark St #2, Chic...
# ...                                                    ...
# 1099759  Dry Goods, 524 Oakbrook Center, Oak Brook, IL ...
# 1099779  Williams Automotive, 1800 Vermont St, Blue Isl...
# 1099896  Doctors of Physical Therapy, merged with Colle...
# 1099899          K B CITGO, 41082 IL-83, Antioch, IL 60002
# 1099941  Starbucks, 11840 S Marshfield Ave, Chicago, IL...
#
#                                        gmap_id  \
# 124      0x880f0f1b32155555:0x8347e0c971acb955
# 125      0x880e5523024703c1:0xb93a8ccb6918d616
# 135      0x8873b548b16a932f:0xaa86fda70cf3b195
# 138       0x8873eb206dd04879:0xb303a76f2c682e4
# 526      0x880fd3ee7195c1bd:0x84d7c59622116e4b
# ...                                        ...
# 1099759  0x880e4c42f77dc4f9:0x8056e7f0f5a037f7
# 1099779  0x880e237d7e673299:0x17c1c978afdfc140
# 1099896  0x880f813908127c51:0xee18719d922d9a92
# 1099899  0x880f8154f5614b71:0x5e62e7a848c5fea6
# 1099941  0x880e24f4782ae337:0x65542e133847bbde
#
#                                                description   latitude  \
# 124                                                   None  42.098159
# 125                                                   None  41.887341
# 135                                                   None  38.989536
# 138                                                   None  38.959944
# 526                                                   None  41.901940
# ...                                                    ...        ...
# 1099759                                               None  41.851432
# 1099779                                               None  41.657216
# 1099896                                               None  42.479510
# 1099899                                               None  42.460434
# 1099941  Seattle-based coffeehouse chain known for its ...  41.679302
#
#          longitude                                           category  \
# 124     -88.275237                                        [Toy store]
# 125     -88.136456                                     [Liquor store]
# 135     -88.177085                                   [Football Field]
# 138     -88.519025                                [Conference center]
# 526     -87.630926  [Auto repair shop, Auto air conditioning servi...
# ...            ...                                                ...
# 1099759 -87.952389  [Women's clothing store, Clothing store, Costu...
# 1099779 -87.665749                                 [Auto repair shop]
# 1099896 -88.102355  [Physical therapist, Physical fitness program,...
# 1099899 -88.092262                                      [Gas station]
# 1099941 -87.664750                                      [Coffee shop]
#
#          avg_rating  num_of_reviews price  \
# 124             4.9              17  None
# 125             3.6               8  None
# 135             4.4              17  None
# 138             4.9              14  None
# 526             3.3              35  None
# ...             ...             ...   ...
# 1099759         4.5              26  None
# 1099779         4.7              64  None
# 1099896         4.9              93  None
# 1099899         3.9              28  None
# 1099941         3.7              18    $$
#
#                                                      hours  \
# 124      [[Thursday, 10AM–8PM], [Friday, 10AM–8PM], [Sa...
# 125      [[Thursday, 10AM–10PM], [Friday, 10AM–10:30PM]...
# 135                                                   None
# 138                                                   None
# 526      [[Thursday, 6AM–10PM], [Friday, 6AM–10PM], [Sa...
# ...                                                    ...
# 1099759  [[Friday, 11AM–8PM], [Saturday, 11AM–8PM], [Su...
# 1099779  [[Friday, 8AM–6PM], [Saturday, Closed], [Sunda...
# 1099896  [[Friday, 5:30AM–4PM], [Saturday, Closed], [Su...
# 1099899  [[Friday, 5AM–10PM], [Saturday, 6AM–10PM], [Su...
# 1099941                                               None
#
#                                                       MISC     state  \
# 124      {'Accessibility': ['Wheelchair accessible entr...  Illinois
# 125      {'Service options': ['In-store shopping', 'Del...  Illinois
# 135      {'Accessibility': ['Wheelchair accessible entr...  Illinois
# 138      {'Accessibility': ['Wheelchair accessible entr...  Illinois
# 526      {'Accessibility': ['Wheelchair accessible entr...  Illinois
# ...                                                    ...       ...
# 1099759  {'Service options': ['In-store shopping', 'Del...  Illinois
# 1099779  {'Accessibility': ['Wheelchair accessible entr...  Illinois
# 1099896  {'Accessibility': ['Wheelchair accessible entr...  Illinois
# 1099899                                               None  Illinois
# 1099941  {'Service options': ['Takeout', 'Delivery', 'D...  Illinois
#
#                                           relative_results  \
# 124      [0x880f72a26e93c371:0xed11dd45ac49ed11, 0x880f...
# 125      [0x880e55410d7a8187:0x9863102d1658ecf2, 0x880e...
# 135                                                   None
# 138      [0x8873bbdf9a504c3d:0x1cf279640439c21f, 0x8873...
# 526      [0x880fd1dba71b87cb:0xb0a40d8eef20c31d, 0x880e...
# ...                                                    ...
# 1099759  [0x880e4c6805240753:0xe2dcd383e27e1400, 0x880e...
# 1099779  [0x880e24a05b46fb4d:0xccd7e1524533bb7b, 0x880e...
# 1099896  [0x880f814bf357e987:0xbfb33e5d1ab83581, 0x880f...
# 1099899  [0x880f8268253f80c9:0x73b9c044d10cd795, 0x880f...
# 1099941  [0x880e247dc7ca1765:0xf1170f23ff5b305, 0x880e2...
#
#                                                        url
# 124      https://www.google.com/maps/place//data=!4m2!3...
# 125      https://www.google.com/maps/place//data=!4m2!3...
# 135      https://www.google.com/maps/place//data=!4m2!3...
# 138      https://www.google.com/maps/place//data=!4m2!3...
# 526      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 1099759  https://www.google.com/maps/place//data=!4m2!3...
# 1099779  https://www.google.com/maps/place//data=!4m2!3...
# 1099896  https://www.google.com/maps/place//data=!4m2!3...
# 1099899  https://www.google.com/maps/place//data=!4m2!3...
# 1099941  https://www.google.com/maps/place//data=!4m2!3...
#
# [16413 rows x 15 columns]

# %% [markdown]
# Verificamos la existencia de valores nulos y tipo de datos

# %%
herramientas.verifica_tipo_y_nulos(df_sitios_illinois)
# Out:
#         nombre_campo                            tipo_datos  no_nulos_%  \
# 0               name                       [<class 'str'>]      100.00
# 1            address   [<class 'str'>, <class 'NoneType'>]       99.48
# 2            gmap_id                       [<class 'str'>]      100.00
# 3        description   [<class 'NoneType'>, <class 'str'>]       16.46
# 4           latitude                     [<class 'float'>]      100.00
# 5          longitude                     [<class 'float'>]      100.00
# 6           category  [<class 'list'>, <class 'NoneType'>]       99.92
# 7         avg_rating                     [<class 'float'>]      100.00
# 8     num_of_reviews                       [<class 'int'>]      100.00
# 9              price   [<class 'NoneType'>, <class 'str'>]       17.64
# 10             hours  [<class 'list'>, <class 'NoneType'>]       85.26
# 11              MISC  [<class 'dict'>, <class 'NoneType'>]       90.11
# 12             state                       [<class 'str'>]      100.00
# 13  relative_results  [<class 'list'>, <class 'NoneType'>]       95.65
# 14               url                       [<class 'str'>]      100.00
#
#     nulos_%  nulos
# 0      0.00      0
# 1      0.52     86
# 2      0.00      0
# 3     83.54  13711
# 4      0.00      0
# 5      0.00      0
# 6      0.08     13
# 7      0.00      0
# 8      0.00      0
# 9     82.36  13517
# 10    14.74   2420
# 11     9.89   1623
# 12     0.00      0
# 13     4.35    714
# 14     0.00      0

# %% [markdown]
# Eliminamos los nulos de la columna 'category'

# %%
# Eliminar filas con valores nulos en la columna 'category'
df_sitios_illinois = df_sitios_illinois.dropna(subset=['category'])

# %% [markdown]
# Verificamos los cambios realizados anteriormente

# %%
herramientas.verifica_tipo_y_nulos(df_sitios_illinois)
# Out:
#         nombre_campo                            tipo_datos  no_nulos_%  \
# 0               name                       [<class 'str'>]      100.00
# 1            address   [<class 'str'>, <class 'NoneType'>]       99.48
# 2            gmap_id                       [<class 'str'>]      100.00
# 3        description   [<class 'NoneType'>, <class 'str'>]       16.47
# 4           latitude                     [<class 'float'>]      100.00
# 5          longitude                     [<class 'float'>]      100.00
# 6           category                      [<class 'list'>]      100.00
# 7         avg_rating                     [<class 'float'>]      100.00
# 8     num_of_reviews                       [<class 'int'>]      100.00
# 9              price   [<class 'NoneType'>, <class 'str'>]       17.66
# 10             hours  [<class 'list'>, <class 'NoneType'>]       85.29
# 11              MISC  [<class 'dict'>, <class 'NoneType'>]       90.18
# 12             state                       [<class 'str'>]      100.00
# 13  relative_results  [<class 'list'>, <class 'NoneType'>]       95.65
# 14               url                       [<class 'str'>]      100.00
#
#     nulos_%  nulos
# 0      0.00      0
# 1      0.52     86
# 2      0.00      0
# 3     83.53  13699
# 4      0.00      0
# 5      0.00      0
# 6      0.00      0
# 7      0.00      0
# 8      0.00      0
# 9     82.34  13504
# 10    14.71   2413
# 11     9.82   1610
# 12     0.00      0
# 13     4.35    714
# 14     0.00      0

# %% [markdown]
# Concatenamos todos los estados

# %%
# Lista de los df_sitios_concat 
df_sitios_concat = [df_sitios_california, df_sitios_illinois, df_sitios_florida, df_sitios_texas, df_sitios_new_york]

df_sitios_estados = pd.concat(df_sitios_concat)

df_sitios_estados
# Out:
#                                              name  \
# 2                                    San Soo Dang
# 4                                Nobel Textile Co
# 5                   Matrix International Textiles
# 6                                    Vons Chicken
# 13       Black Tie Ski Rental Delivery of Mammoth
# ...                                           ...
# 1099746       Creek-N-Wood RV Park and Campground
# 1099747                 Absolute Automotive of Ny
# 1099751              Michael Prouty Memorial Park
# 1099848                               Cafe Booqoo
# 1099854                      Lida's Beauty Lounge
#
#                                                    address  \
# 2        San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 4        Nobel Textile Co, 719 E 9th St, Los Angeles, C...
# 5        Matrix International Textiles, 1363 S Bonnie B...
# 6        Vons Chicken, 12740 La Mirada Blvd, La Mirada,...
# 13       Black Tie Ski Rental Delivery of Mammoth, 501 ...
# ...                                                    ...
# 1099746  Creek-N-Wood RV Park and Campground, 2530 Whee...
# 1099747  Absolute Automotive of Ny, 2310 Walworth-Mario...
# 1099751  Michael Prouty Memorial Park, 2402-2474 NY-65,...
# 1099848      Cafe Booqoo, 478 Smith St, Brooklyn, NY 11231
# 1099854  Lida's Beauty Lounge, 2624 Broadway, New York,...
#
#                                        gmap_id description   latitude  \
# 2        0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092
# 4        0x80c2c632f933b073:0xc31785961fe826a6        None  34.036694
# 5        0x80c2cf163db6bc89:0x219484e2edbcfa41        None  34.015505
# 6        0x80dd2b4c8555edb7:0xfc33d65c4bdbef42        None  33.916402
# 13       0x80960c29f2e3bf29:0x4b291f0d275a5699        None  37.638754
# ...                                        ...         ...        ...
# 1099746  0x89d13ad30c7fcaff:0x3c01448f5da558dd        None  42.906084
# 1099747  0x89d6d41470c5dbf5:0x66461848781795d3        None  43.138831
# 1099751  0x89d1388d4acc026f:0x30a872bfd0a4679d        None  42.908991
# 1099848  0x89c25af6e18e56a5:0x9b38fce3dbd88098        None  40.674726
# 1099854  0x89c2f768aac90c8b:0x3decd1160a13170b        None  40.796580
#
#           longitude                                           category  \
# 2       -118.292130                                [Korean restaurant]
# 4       -118.249421                                     [Fabric store]
# 5       -118.181839                                     [Fabric store]
# 6       -118.010855                                       [Restaurant]
# 13      -118.966055     [Ski rental service, Snowboard rental service]
# ...             ...                                                ...
# 1099746  -77.380880                                       [Campground]
# 1099747  -77.268383                                 [Auto repair shop]
# 1099751  -77.539035                                             [Park]
# 1099848  -73.997918  [Creole restaurant, Breakfast restaurant, Cafe...
# 1099854  -73.969919                           [Hair salon, Nail salon]
#
#          avg_rating  num_of_reviews price  \
# 2               4.4              18  None
# 4               4.3               7  None
# 5               3.5               6  None
# 6               4.5              18  None
# 13              5.0              34  None
# ...             ...             ...   ...
# 1099746         4.5              58  None
# 1099747         4.9              45  None
# 1099751         4.1              16  None
# 1099848         4.5              68  None
# 1099854         4.8              38  None
#
#                                                      hours  \
# 2        [[Thursday, 6:30AM–6PM], [Friday, 6:30AM–6PM],...
# 4        [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 5        [[Thursday, 8:30AM–5:30PM], [Friday, 8:30AM–5:...
# 6        [[Thursday, 11AM–9:30PM], [Friday, 11AM–9:30PM...
# 13       [[Thursday, 8AM–5PM], [Friday, 8AM–5PM], [Satu...
# ...                                                    ...
# 1099746                                               None
# 1099747  [[Friday, 8AM–6PM], [Saturday, Closed], [Sunda...
# 1099751  [[Friday, 8AM–6PM], [Saturday, 8AM–6PM], [Sund...
# 1099848  [[Friday, 11AM–8PM], [Saturday, 9AM–4PM], [Sun...
# 1099854  [[Friday, 9AM–8PM], [Saturday, 9AM–8PM], [Sund...
#
#                                                       MISC       state  \
# 2        {'Service options': ['Takeout', 'Dine-in', 'De...  California
# 4                 {'Service options': ['In-store pickup']}  California
# 5        {'Accessibility': ['Wheelchair accessible entr...  California
# 6        {'Service options': ['Outdoor seating', 'Curbs...  California
# 13       {'Accessibility': ['Wheelchair accessible entr...  California
# ...                                                    ...         ...
# 1099746  {'Accessibility': ['Wheelchair accessible entr...    New York
# 1099747  {'Accessibility': ['Wheelchair accessible entr...    New York
# 1099751  {'Accessibility': ['Wheelchair accessible entr...    New York
# 1099848  {'Service options': ['Takeout', 'Delivery'], '...    New York
# 1099854  {'From the business': ['Identifies as women-le...    New York
#
#                                           relative_results  \
# 2        [0x80c2c78249aba68f:0x35bf16ce61be751d, 0x80c2...
# 4        [0x80c2c62c496083d1:0xdefa11317fe870a1, 0x80c2...
# 5        [0x80c2cf042a5d9561:0xd0024ad6f81f1335, 0x80c2...
# 6                                                     None
# 13       [0x80960dcd6ba76731:0x9a6875ced2f9228e, 0x8096...
# ...                                                    ...
# 1099746  [0x89d13d78ddf709e5:0x80dc7df9525a6103, 0x873b...
# 1099747  [0x89d6d413ac3b37c9:0xe8f4ed0862cd4c0a, 0x89d6...
# 1099751  [0x89d13ba56ebef6a1:0x196f02728d220a25, 0x89d1...
# 1099848  [0x89c25a4e53443397:0xecc6f06f74f11410, 0x89c2...
# 1099854  [0x89c2f6260bfa97d5:0x9183d760186c18cd, 0x89c2...
#
#                                                        url
# 2        https://www.google.com/maps/place//data=!4m2!3...
# 4        https://www.google.com/maps/place//data=!4m2!3...
# 5        https://www.google.com/maps/place//data=!4m2!3...
# 6        https://www.google.com/maps/place//data=!4m2!3...
# 13       https://www.google.com/maps/place//data=!4m2!3...
# ...                                                    ...
# 1099746  https://www.google.com/maps/place//data=!4m2!3...
# 1099747  https://www.google.com/maps/place//data=!4m2!3...
# 1099751  https://www.google.com/maps/place//data=!4m2!3...
# 1099848  https://www.google.com/maps/place//data=!4m2!3...
# 1099854  https://www.google.com/maps/place//data=!4m2!3...
#
# [124558 rows x 15 columns]

# %% [markdown]
# Eliminamos las columnas 'descripcion' y 'price'

# %%
df_sitios_estados = df_sitios_estados.drop(['description', 'price'], axis=1)

# %% [markdown]
# Elimino los valores nulos de la columna 'category'

# %%
# Eliminar filas con valores nulos en la columna 'category'
df_sitios_estados = df_sitios_estados.dropna(subset=['category'])

# %% [markdown]
# Elimino los valores nulos de la columna 'name'

# %%
# Eliminar filas con valores nulos en la columna 'name'
df_sitios_estados = df_sitios_estados.dropna(subset=['name'])

# %% [markdown]
# Verificamos valores nulos y tipo de datos

# %%
herramientas.verifica_tipo_y_nulos(df_sitios_estados)
# Out:
#         nombre_campo                            tipo_datos  no_nulos_%  \
# 0               name                       [<class 'str'>]      100.00
# 1            address   [<class 'str'>, <class 'NoneType'>]       99.08
# 2            gmap_id                       [<class 'str'>]      100.00
# 3           latitude                     [<class 'float'>]      100.00
# 4          longitude                     [<class 'float'>]      100.00
# 5           category                      [<class 'list'>]      100.00
# 6         avg_rating                     [<class 'float'>]      100.00
# 7     num_of_reviews                       [<class 'int'>]      100.00
# 8              hours  [<class 'list'>, <class 'NoneType'>]       86.69
# 9               MISC  [<class 'dict'>, <class 'NoneType'>]       89.19
# 10             state                       [<class 'str'>]      100.00
# 11  relative_results  [<class 'list'>, <class 'NoneType'>]       95.03
# 12               url                       [<class 'str'>]      100.00
#
#     nulos_%  nulos
# 0      0.00      0
# 1      0.92   1147
# 2      0.00      0
# 3      0.00      0
# 4      0.00      0
# 5      0.00      0
# 6      0.00      0
# 7      0.00      0
# 8     13.31  16579
# 9     10.81  13469
# 10     0.00      0
# 11     4.97   6187
# 12     0.00      0

# %% [markdown]
# Verifico el tipo de dato del dataframe

# %%
df_sitios_estados.info()

# %% [markdown]
# Exportamos el dataframe

# %%
# Exportar el DataFrame
df_sitios_estados.to_csv('df_sitios_estados.csv', escapechar='\\', index=False)
